# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gtsa

# %% [markdown]
# ### Plot a single COG

# %%
cog_url = 'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1947-09-14_EE_reproj_COG.tif'

# %%
m = gtsa.plotting.plot_cog(cog_url   = cog_url,
                       zoom_start = 11)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dca521976da43d88a32d7fee46141b86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dca521976da43d88a32d7fee46141b86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dca521976da43d88a32d7fee46141b86 = L.map(
#                 &quot;map_dca521976da43d88a32d7fee46141b86&quot;,
#                 {
#                     center: [48.74868358908725, -121.78096499929248],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_dca521976da43d88a32d7fee46141b86);
#
#
#
#
#
#             var tile_layer_20c185f172efafd22f9b503441d19dd7 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 0.8, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dca521976da43d88a32d7fee46141b86);
#
#
#             var tile_layer_c37e25da17517ed1c5e1f6bd45b88d32 = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1947-09-14_EE_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dca521976da43d88a32d7fee46141b86);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# m.save('mount_baker_1947-09-14.html')

# %% [markdown]
# ### Plot multiple cogs

# %%
s3_bucket_name = 'conus-historicals'
folder_path = 'baker/orthos'

# %%
cog_urls = gtsa.io.parse_urls_from_S3_bucket(s3_bucket_name,
                                             folder = folder_path,
                                             aws_server_url = 's3.amazonaws.com')

dates = gtsa.io.parse_timestamps(cog_urls,
                                 date_string_pattern='....-..-..')

# %%
map_center_lon = -121.8144
map_center_lat = 48.7767

m = gtsa.plotting.plot_cogs(cog_urls,
                        dates,
                        map_center_lon      = map_center_lon,
                        map_center_lat      = map_center_lat,
                        zoom_start          = 11,
                        overview_cog_index  = 0,
                        print_info          = True,
                       )
m
# Out:
# map center: -121.8144 48.7767
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a63e16f59651a393cb90c7f593134a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a63e16f59651a393cb90c7f593134a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a63e16f59651a393cb90c7f593134a5 = L.map(
#                 &quot;map_9a63e16f59651a393cb90c7f593134a5&quot;,
#                 {
#                     center: [48.7767, -121.8144],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9a63e16f59651a393cb90c7f593134a5);
#
#
#
#
#
#             var tile_layer_10f6fb25e68de46b7f8d5f4bd0080abc = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 0.8, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a63e16f59651a393cb90c7f593134a5);
#
#
#             var tile_layer_e2fe002f58087c48f9210e0ac3034572 = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1947-09-14_EE_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a63e16f59651a393cb90c7f593134a5);
#
#
#             var tile_layer_2704e734eb2436095f8cd15da38b3aa0 = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1970-09-09_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a63e16f59651a393cb90c7f593134a5);
#
#
#             var tile_layer_43b5cd2d7c5523e4f291186a79d93ce5 = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1970-09-29_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a63e16f59651a393cb90c7f593134a5);
#
#
#             var tile_layer_d94a3a1152552aac477981dbcb04cd57 = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1974-08-10_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a63e16f59651a393cb90c7f593134a5);
#
#
#             var tile_layer_1b13439010bd2a49780526769250e098 = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1977-09-27_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a63e16f59651a393cb90c7f593134a5);
#
#
#             var tile_layer_1efa874a33a532c9b2c51bda92af382c = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1979-10-06_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: fal

# %%
# m.save('mount_baker_all.html')

# %% [markdown]
# ### Plot multiple sites

# %%
s3_bucket_name = 'conus-historicals'

# %%
sites = ['baker','scg']
folders = [gtsa.io.Path(s, 'orthos').as_posix() for s in sites]

site_marker_names = ['Mount Baker', 'South Cascade']
site_marker_coords = [(48.7767, -121.8144), (48.3717, -121.0660)]
cog_overview_indices = [0,0]

map_center = (48.5485, -121.4045)

# %%
payload = {}
payload['map_center'] = map_center
payload['sites'] = {}

for i, site in enumerate(sites):
    payload['sites'][site] = {'marker_name':site_marker_names[i],
                              'marker_coords': site_marker_coords[i],
                     'overview_index': cog_overview_indices[i],
                     'cog_urls': gtsa.io.parse_urls_from_S3_bucket(s3_bucket_name,
                                                                   folder = folders[i],
                                                                   aws_server_url = 's3.amazonaws.com'),
                             }
    payload['sites'][site]['dates'] = gtsa.io.parse_timestamps(payload['sites'][site]['cog_urls'])
    payload['sites'][site]['cog_names'] = [site +'_'+ x for x in payload['sites'][site]['dates']]

# %%
m = gtsa.plotting.plot_cogs_sites(payload,
                                  zoom_start           = 9,
                                  print_info          = True,
                             )
m
# Out:
# map center: -121.4045 48.5485
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2869016e705596c3f7a53f02742924c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2869016e705596c3f7a53f02742924c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2869016e705596c3f7a53f02742924c2 = L.map(
#                 &quot;map_2869016e705596c3f7a53f02742924c2&quot;,
#                 {
#                     center: [48.5485, -121.4045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2869016e705596c3f7a53f02742924c2);
#
#
#
#
#
#             var tile_layer_280ab1ffe25fc7e850f5475b7eaa8e05 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 0.8, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2869016e705596c3f7a53f02742924c2);
#
#
#             var feature_group_d674e3d82c251dbd0cfa4d42574a5292 = L.featureGroup(
#                 {}
#             ).addTo(map_2869016e705596c3f7a53f02742924c2);
#
#
#             var tile_layer_527fd5abe77853765e1000118ae8a107 = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1970-09-09_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(feature_group_d674e3d82c251dbd0cfa4d42574a5292);
#
#
#             var tile_layer_2acacd8541f3a2ee9096de4b72610e8c = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1970-09-29_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(feature_group_d674e3d82c251dbd0cfa4d42574a5292);
#
#
#             var tile_layer_e7c2fe30d91d510f8cc6e7f3fdee4e1b = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1974-08-10_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(feature_group_d674e3d82c251dbd0cfa4d42574a5292);
#
#
#             var tile_layer_49788f968c427e5d637f3d8a4fab7122 = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1977-09-27_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(feature_group_d674e3d82c251dbd0cfa4d42574a5292);
#
#
#             var tile_layer_7065b47d08cf0b0d529dc74ef15617ed = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/{z}/{x}/{y}?url=http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1979-10-06_NG_reproj_COG.tif\u0026expression=b1\u0026rescale=0,255&quot;,
#                 {&quot;attribution&quot;: &quot;gtsa&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(feature_group_d674e3d8

# %%
# m.save('Mount_Baker-South_Cascade.html')

# %%
payload
# Out:
# {'map_center': (48.5485, -121.4045),
#  'sites': {'baker': {'marker_name': 'Mount Baker',
#    'marker_coords': (48.7767, -121.8144),
#    'overview_index': 0,
#    'cog_urls': ['http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1947-09-14_EE_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1970-09-09_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1970-09-29_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1974-08-10_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1977-09-27_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1979-10-06_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1987-08-21_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1990-09-05_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1991-09-09_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1992-09-15_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/baker/orthos/ortho_1992-09-18_NG_reproj_COG.tif'],
#    'dates': ['1947-09-14',
#     '1970-09-09',
#     '1970-09-29',
#     '1974-08-10',
#     '1977-09-27',
#     '1979-10-06',
#     '1987-08-21',
#     '1990-09-05',
#     '1991-09-09',
#     '1992-09-15',
#     '1992-09-18'],
#    'cog_names': ['baker_1947-09-14',
#     'baker_1970-09-09',
#     'baker_1970-09-29',
#     'baker_1974-08-10',
#     'baker_1977-09-27',
#     'baker_1979-10-06',
#     'baker_1987-08-21',
#     'baker_1990-09-05',
#     'baker_1991-09-09',
#     'baker_1992-09-15',
#     'baker_1992-09-18']},
#   'scg': {'marker_name': 'South Cascade',
#    'marker_coords': (48.3717, -121.066),
#    'overview_index': 0,
#    'cog_urls': ['http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1967-09-21_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1970-09-29_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1974-08-10_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1977-10-03_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1979-08-20_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1979-10-06_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1984-08-14_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1986-09-05_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1987-08-21_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1990-09-05_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1991-09-09_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1992-07-28_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1992-09-15_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1992-09-18_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1992-10-06_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1994-09-06_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1996-09-10_NG_reproj_COG.tif',
#     'http://conus-historicals.s3.amazonaws.com/scg/orthos/ortho_1997-09-23_NG_reproj_COG.tif'],
#    'dates': ['1967-09-21',
#     '1970-09-29',
#     '1974-08-10',
#     '1977-10-03',
#     '1979-08-20',
#     '1979-10-06',
#     '1984-08-14',
#     '1986-09-05',
#     '1987-08-21',
#     '1990-09-05',
#     '1991-09-09',
#     '1992-07-28',
#     '1992-09-15',
#     '1992-09-18',
#     '1992-10-06',
#     '1994-09-06',
#     '1996-09-10',
#     '1997-09-23'],
#    'cog_names': ['scg_1967-09-21',
#     'scg_1970-09-29',
#     'scg_1974-08-10',
#     'scg_1977-10-03',
#     'scg_1979-08-20',
#     'scg_1979-10-06',
#     'scg_1984-08-14',
#     'scg_1986-09-05',
#     'scg_1987-08-21',
#     'scg_1990-09-05',
#     'scg_1991-09-09',
#     'scg_1992-07-28',
#     'scg_1992-09-15',
#     'scg_1992-09-18',
#     'scg_1992-10-06',
#     'scg_1994-09-06',
#     'scg_1996-09-10',
#     'scg_1997-09-23']}}}
