# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gtsa

from pathlib import Path
import shutil
import psutil
import pandas as pd
import hvplot.xarray
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# # Raster stacking
#
# Stacks single band rasters and chunks along the time dimension (on disk) for memory-efficient data retrieval.
#
# #### Prerequesites
# - Download DEM data with `00_download_dem_data.py` or `00_download_dem_data.ipynb`

# %% [markdown]
# ## Start dask cluster
# - For parallel read/write

# %%
workers = psutil.cpu_count(logical=True)-1
client = gtsa.io.dask_start_cluster(workers,
                                    ip_address=None, # replace with address if working on remote machine
                                    port='8787', # if occupies a different port will automatically be assigned
                                   )
# Out:
# Dask dashboard at: http://127.0.0.1:8787/status
# Workers: 31
# Threads per worker: 1

# %% [markdown]
# ## Get DEM file paths and time stamps

# %%
# data_dir = '../../data/dems/south-cascade/' # small test dataset
data_dir = '../../data/dems/mount-baker' # large dataset

# %%
dems = [x.as_posix() for x in sorted(Path(data_dir).glob('*.tif'))]
date_strings = [x[1:-1] for x in gtsa.io.parse_timestamps(dems,date_string_pattern='_........_')]
date_strings, dems = list(zip(*sorted(zip(date_strings, dems)))) # ensure chronological sorting 
date_times = [pd.to_datetime(x, format="%Y%m%d") for x in date_strings]

# %%
ref_dem = dems[-1] # always last after chronological sorting
ref_dem
# Out:
# '../../data/dems/mount-baker/WADNR_mount-baker_20150827_1m_dem.tif'

# %% [markdown]
# ## Reproject to reference DEM grid
# - Create a reprojected NetCDF file for each DEM
# - Loads all NetCDF files lazily

# %%
ds = gtsa.io.xr_stack_geotifs(dems,
                              date_times,
                              ref_dem,
                              resampling="bilinear",
                              save_to_nc = True,
                              nc_out_dir = Path(data_dir,'nc_files').as_posix(),
                              overwrite = False)
# Out:
# Reading files from ../../data/dems/mount-baker/nc_files

# %% [markdown]
# ## Examine current chunk shape
# - Each time stamped DEM is a single chunk

# %%
ds['band1']
# Out:
# <xarray.DataArray 'band1' (time: 11, y: 28392, x: 19282)>
# dask.array<concatenate, shape=(11, 28392, 19282), dtype=float32, chunksize=(1, 7029, 4773), chunktype=numpy.ndarray>
# Coordinates:
#   * x            (x) float64 5.73e+05 5.73e+05 5.73e+05 ... 5.922e+05 5.922e+05
#   * y            (y) float64 5.414e+06 5.414e+06 ... 5.386e+06 5.386e+06
#     spatial_ref  int64 0
#   * time         (time) datetime64[ns] 1970-09-09 1970-09-29 ... 2015-08-27
# Attributes:
#     AREA_OR_POINT:  Area
#     grid_mapping:   spatial_ref

# %%
ds['band1'].sel(time = ds.time.values[0])
# Out:
# <xarray.DataArray 'band1' (y: 28392, x: 19282)>
# dask.array<getitem, shape=(28392, 19282), dtype=float32, chunksize=(7029, 4773), chunktype=numpy.ndarray>
# Coordinates:
#   * x            (x) float64 5.73e+05 5.73e+05 5.73e+05 ... 5.922e+05 5.922e+05
#   * y            (y) float64 5.414e+06 5.414e+06 ... 5.386e+06 5.386e+06
#     spatial_ref  int64 0
#     time         datetime64[ns] 1970-09-09
# Attributes:
#     AREA_OR_POINT:  Area
#     grid_mapping:   spatial_ref

# %% [markdown]
# ## Rechunk along time dimension
# - Creates temporary zarr file for efficient rechunking
# - Saves a zarr file chunked along full time dimension to disk
# - Significantly improves dask worker occupation and processing time for computations along the time dimension

# %%
ds_zarr = gtsa.io.create_zarr_stack(ds,
                                    output_directory = Path(data_dir,'stack').as_posix(),
                                    variable_name='band1',
                                    zarr_stack_file_name='stack.zarr',
                                    overwrite = False,
                                    cleanup=True)
# Out:
# Creating temporary zarr stack
# /
#  ├── band1 (11, 28392, 19282) float32
#  ├── time (11,) int64
#  ├── x (19282,) float64
#  └── y (28392,) float64
# Name               : /band1
# Type               : zarr.core.Array
# Data type          : float32
# Shape              : (11, 28392, 19282)
# Chunk shape        : (1, 5679, 3857)
# Order              : C
# Read-only          : False
# Compressor         : Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)
# Store type         : zarr.storage.DirectoryStore
# No. bytes          : 24087999936 (22.4G)
# No. bytes stored   : 1963497325 (1.8G)
# Storage ratio      : 12.3
# Chunks initialized : 275/275
#
# Rechunking temporary zarr stack and saving as
# ../../data/dems/mount-baker/stack/stack.zarr
# Rechunked zarr file info
# /
#  ├── band1 (11, 28392, 19282) float32
#  ├── time (11,) int64
#  ├── x (19282,) float64
#  └── y (28392,) float64
# Name               : /band1
# Type               : zarr.core.Array
# Data type          : float32
# Shape              : (11, 28392, 19282)
# Chunk shape        : (11, 1775, 1206)
# Order              : C
# Read-only          : False
# Compressor         : Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)
# Store type         : zarr.storage.DirectoryStore
# No. bytes          : 24087999936 (22.4G)
# No. bytes stored   : 1952777454 (1.8G)
# Storage ratio      : 12.3
# Chunks initialized : 256/256
#
# Removing temporary zarr stack
# Dask chunk size:
# Chunk shape: (11,259,176)
# Chunk size: 2005696 (2.0M)

# %%
ds_zarr['band1']

# %%
ds_zarr['band1'].sel(time = ds_zarr.time.values[0])

# %%
ll ../../data/dems/mount-baker/

# %%
rm -rf ../../data/dems/mount-baker/stack

# %%
rm -rf ../../data/dems/mount-baker/nc_files

# %%
client.get_versions(check=True)
# Out:
# {'scheduler': {'host': {'python': '3.11.4.final.0',
#    'python-bits': 64,
#    'OS': 'Linux',
#    'OS-release': '5.15.0-76-generic',
#    'machine': 'x86_64',
#    'processor': 'x86_64',
#    'byteorder': 'little',
#    'LC_ALL': 'None',
#    'LANG': 'en_US.UTF-8'},
#   'packages': {'python': '3.11.4.final.0',
#    'dask': '2023.7.0',
#    'distributed': '2023.7.0',
#    'msgpack': '1.0.5',
#    'cloudpickle': '2.2.1',
#    'tornado': '6.3.2',
#    'toolz': '0.12.0',
#    'numpy': '1.24.4',
#    'pandas': '2.0.3',
#    'lz4': '4.3.2'}},
#  'workers': {'tcp://127.0.0.1:33119': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:33137': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:33303': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:33731': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:34067': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:34407': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:34795': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:35665': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:35729': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:36651': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:37033': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:37157': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:38601': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:38983': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:39145': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:39437': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:41037': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:41413': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:41415': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:41597': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:42681': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:43429': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:44051': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:44365': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:44489': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:45215': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:45873': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:46257': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:46393': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:46413': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:46883': {'host': {'python': '3.11.4.final.0',
#     'python-bits': 64,
#     'OS': 'Linux',
#     'OS-release': '5.15.0-76-generic',
#     'machine': 'x86_64',
#     'processor': 'x86_64',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'en_US.UTF-8'},
#    'packages': {'python': '3.11.4.final.0',
#     'dask': '2023.7.0',
#     'distributed': '2023.7.0',
#     'msgpack': '1.0.5',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.2',
#     'toolz': '0.12.0',
#     'numpy': '1.24.4',
#     'pandas': '2.0.3',
#     'lz4': '4.3.2'}}},
#  'client': {'host': {'python': '3.11.4.final.0',
#    'python-bits': 64,
#    'OS': 'Linux',
#    'OS-release': '5.15.0-76-generic',
#    'machine': 'x86_64',
#    'processor': 'x86_64',
#    'byteorder': 'little',
#    'LC_ALL': 'None',
#    'LANG': 'en_US.UTF-8'},
#   'packages': {'python': '3.11.4.final.0',
#    'dask': '2023.7.0',
#    'distributed': '2023.7.0',
#    'msgpack': '1.0.5',
#    'cloudpickle': '2.2.1',
#    'tornado': '6.3.2',
#    'toolz': '0.12.0',
#    'numpy': '1.24.4',
#    'pandas': '2.0.3',
#    'lz4': '4.3.2'}}}

# %%
distributed.dask_worker
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 distributed.dask_worker
#
# NameError: name 'distributed' is not defined

# %%
import distributed

# %%
distributed.scheduler.
# Out:
# <module 'distributed.scheduler' from '/mnt/working/knuth/sw/miniconda3/envs/gtsa/lib/python3.11/site-packages/distributed/scheduler.py'>
